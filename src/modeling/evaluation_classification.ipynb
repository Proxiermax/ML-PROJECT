# %%
import os
import matplotlib.pyplot as plt
import importlib
import numpy as np
import pickle
from pathlib import Path

# %%
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "models").exists():
    PROJECT_ROOT = Path(__file__).resolve().parents[2] if '__file__' in dir() else Path.cwd()
    while not (PROJECT_ROOT / "models").exists() and PROJECT_ROOT != PROJECT_ROOT.parent:
        PROJECT_ROOT = PROJECT_ROOT.parent

os.chdir(PROJECT_ROOT)

SCRATCH_MODEL_DIR = PROJECT_ROOT / "models" / "classification" / "scratch"
LIB_MODEL_DIR = PROJECT_ROOT / "models" / "classification" / "lib"

def load_classification_model(model_name, source="scratch"):
    base = SCRATCH_MODEL_DIR if source == "scratch" else LIB_MODEL_DIR
    path = base / model_name / "model.pkl"
    if path.exists():
        with open(path, "rb") as f:
            pkg = pickle.load(f)
        print(f"Loaded {source}/{model_name} from {path}")
        return pkg
    else:
        print(f"No saved model at {path} — run training cell")
        return None

# %%
_pkg = load_classification_model("logistic_regression", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_logistic_metrics = _pkg["metrics"]

_pkg = load_classification_model("perceptron", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_perceptron_metrics = _pkg["metrics"]

_pkg = load_classification_model("slp", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_slp_metrics = _pkg["metrics"]

_pkg = load_classification_model("mlp", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_mlp_metrics = _pkg["metrics"]

_pkg = load_classification_model("decision_tree", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_decision_tree_metrics = _pkg["metrics"]

_pkg = load_classification_model("random_forest", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_random_forest_metrics = _pkg["metrics"]

_pkg = load_classification_model("pca_random_forest", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_pca_random_forest_metrics = _pkg["metrics"]

_pkg = load_classification_model("svm", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_svm_metrics = _pkg["metrics"]

_pkg = load_classification_model("pca_svm", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_pca_svm_metrics = _pkg["metrics"]

_pkg = load_classification_model("kmeans", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_kmeans_metrics = _pkg["metrics"]

_pkg = load_classification_model("agglomerative", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_agglomerative_metrics = _pkg["metrics"]

_pkg = load_classification_model("clustering", "scratch")
if _pkg:
    scratch_clustering_metrics = (_pkg["km_metrics"], _pkg["agglo_metrics"])

_pkg = load_classification_model("xgboost", "scratch")
if _pkg and "metrics" in _pkg:
    scratch_xgboost_metrics = _pkg["metrics"]

_pkg = load_classification_model("logistic_regression", "lib")
if _pkg and "metrics" in _pkg:
    sklearn_logistic_metrics = _pkg["metrics"]

_pkg = load_classification_model("perceptron", "lib")
if _pkg and "metrics" in _pkg:
    sklearn_perceptron_metrics = _pkg["metrics"]

_pkg = load_classification_model("slp", "lib")
if _pkg and "metrics" in _pkg:
    lib_slp_metrics = _pkg["metrics"]

_pkg = load_classification_model("mlp", "lib")
if _pkg and "metrics" in _pkg:
    sklearn_mlp_metrics = _pkg["metrics"]

_pkg = load_classification_model("decision_tree", "lib")
if _pkg and "metrics" in _pkg:
    sklearn_decision_tree_metrics = _pkg["metrics"]

_pkg = load_classification_model("random_forest", "lib")
if _pkg and "metrics" in _pkg:
    sklearn_random_forest_metrics = _pkg["metrics"]

_pkg = load_classification_model("pca_random_forest", "lib")
if _pkg and "metrics" in _pkg:
    lib_pca_random_forest_metrics = _pkg["metrics"]

_pkg = load_classification_model("svm", "lib")
if _pkg and "metrics" in _pkg:
    sklearn_svm_metrics = _pkg["metrics"]

_pkg = load_classification_model("pca_svm", "lib")
if _pkg and "metrics" in _pkg:
    lib_pca_svm_metrics = _pkg["metrics"]

_pkg = load_classification_model("kmeans", "lib")
if _pkg and "metrics" in _pkg:
    lib_kmeans_metrics = _pkg["metrics"]

_pkg = load_classification_model("agglomerative", "lib")
if _pkg and "metrics" in _pkg:
    lib_agglomerative_metrics = _pkg["metrics"]

_pkg = load_classification_model("clustering", "lib")
if _pkg:
    sklearn_clustering_metrics = (_pkg["km_metrics"], _pkg["agglo_metrics"])

del _pkg
print("\n--- All available models loaded. You can skip to evaluation cells. ---")
# Out:
# d:\SECTION\ML-PROJECT\.venv\lib\site-packages\sklearn\base.py:442: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.8.0 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Loaded scratch/logistic_regression from d:\SECTION\ML-PROJECT\models\classification\scratch\logistic_regression\model.pkl
# Loaded scratch/perceptron from d:\SECTION\ML-PROJECT\models\classification\scratch\perceptron\model.pkl
# Loaded scratch/slp from d:\SECTION\ML-PROJECT\models\classification\scratch\slp\model.pkl
# Loaded scratch/mlp from d:\SECTION\ML-PROJECT\models\classification\scratch\mlp\model.pkl
# Loaded scratch/decision_tree from d:\SECTION\ML-PROJECT\models\classification\scratch\decision_tree\model.pkl
# Loaded scratch/random_forest from d:\SECTION\ML-PROJECT\models\classification\scratch\random_forest\model.pkl
# Loaded scratch/pca_random_forest from d:\SECTION\ML-PROJECT\models\classification\scratch\pca_random_forest\model.pkl
# Loaded scratch/svm from d:\SECTION\ML-PROJECT\models\classification\scratch\svm\model.pkl
# Loaded scratch/pca_svm from d:\SECTION\ML-PROJECT\models\classification\scratch\pca_svm\model.pkl
# Loaded scratch/kmeans from d:\SECTION\ML-PROJECT\models\classification\scratch\kmeans\model.pkl
# Loaded scratch/agglomerative from d:\SECTION\ML-PROJECT\models\classification\scratch\agglomerative\model.pkl
# Loaded scratch/clustering from d:\SECTION\ML-PROJECT\models\classification\scratch\clustering\model.pkl
# Loaded scratch/xgboost from d:\SECTION\ML-PROJECT\models\classification\scratch\xgboost\model.pkl
# Loaded lib/logistic_regression from d:\SECTION\ML-PROJECT\models\classification\lib\logistic_regression\model.pkl
# Loaded lib/perceptron from d:\SECTION\ML-PROJECT\models\classification\lib\perceptron\model.pkl
# Loaded lib/slp from d:\SECTION\ML-PROJECT\models\classification\lib\slp\model.pkl
# Loaded lib/mlp from d:\SECTION\ML-PROJECT\models\classification\lib\mlp\model.pkl
# Loaded lib/decision_tree from d:\SECTION\ML-PROJECT\models\classification\lib\decision_tree\model.pkl
# Loaded lib/random_forest from d:\SECTION\ML-PROJECT\models\classification\lib\random_forest\model.pkl
# Loaded lib/pca_random_forest from d:\SECTION\ML-PROJECT\models\classification\lib\pca_random_forest\model.pkl
# Loaded lib/svm from d:\SECTION\ML-PROJECT\models\classification\lib\svm\model.pkl
# Loaded lib/pca_svm from d:\SECTION\ML-PROJECT\models\classification\lib\pca_svm\model.pkl
# Loaded lib/kmeans from d:\SECTION\ML-PROJECT\models\classification\lib\kmeans\model.pkl
# Loaded lib/agglomerative from d:\SECTION\ML-PROJECT\models\classification\lib\agglomerative\model.pkl
# Loaded lib/clustering from d:\SECTION\ML-PROJECT\models\classification\lib\clustering\model.pkl
#
# --- All available models loaded. You can skip to evaluation cells. ---

# %%
# --- Logistic Regression (Scratch) ---
import src.modeling.classification.scratch.logistic_regression.train as scratch_logistic_train
importlib.reload(scratch_logistic_train)
scratch_logistic_metrics = scratch_logistic_train.train()
# Out:
# ============================================================
# Logistic Regression (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#   Iteration 0, Loss: 0.693147
#   Iteration 200, Loss: 0.621959
#   Iteration 400, Loss: 0.578414
#   Iteration 600, Loss: 0.546774
#   Iteration 800, Loss: 0.521957
#
# --- Test Results (scratch) ---
#   Accuracy:    0.8396
#   Precision:   0.8865
#   Recall:      0.6831
#   Specificity: 0.9425
#   F1-Score:    0.7716
#   Confusion Matrix: TP=5419  FP=694  FN=2514  TN=11373
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\logistic_regression\model.pkl

# %%
# --- Perceptron (Scratch) ---
import src.modeling.classification.scratch.perceptron.train as scratch_perceptron_train
importlib.reload(scratch_perceptron_train)
scratch_perceptron_metrics = scratch_perceptron_train.train()
# Out:
# ============================================================
# Perceptron / SLP (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#   Epoch 0, Errors: 7722, Acc: 0.9035
#   Epoch 200, Errors: 7354, Acc: 0.9081
#   Epoch 400, Errors: 7331, Acc: 0.9084
#   Epoch 600, Errors: 7306, Acc: 0.9087
#   Epoch 800, Errors: 7312, Acc: 0.9086
#
# --- Test Results (scratch) ---
#   Accuracy:    0.9031
#   Precision:   0.9125
#   Recall:      0.8357
#   Specificity: 0.9473
#   F1-Score:    0.8724
#   Confusion Matrix: TP=6630  FP=636  FN=1303  TN=11431
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\perceptron\model.pkl

# %%
# --- MLP (Scratch) ---
import src.modeling.classification.scratch.mlp.train as scratch_mlp_train
importlib.reload(scratch_mlp_train)
scratch_mlp_metrics = scratch_mlp_train.train()
# Out:
# ============================================================
# Multi-Layer Perceptron (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#   Epoch 0, Loss: 0.900393, Acc: 0.3639
#   Epoch 100, Loss: 0.605473, Acc: 0.6846
#   Epoch 200, Loss: 0.501098, Acc: 0.7937
#   Epoch 300, Loss: 0.433399, Acc: 0.8459
#   Epoch 400, Loss: 0.383424, Acc: 0.8721
#
# --- Test Results (scratch) ---
#   Accuracy:    0.8890
#   Precision:   0.8677
#   Recall:      0.8496
#   Specificity: 0.9148
#   F1-Score:    0.8585
#   Confusion Matrix: TP=6740  FP=1028  FN=1193  TN=11039
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\mlp\model.pkl

# %%
# --- Decision Tree (Scratch) ---
import src.modeling.classification.scratch.decision_tree.train as scratch_decision_tree_train
importlib.reload(scratch_decision_tree_train)
scratch_decision_tree_metrics = scratch_decision_tree_train.train()
# Out:
# ============================================================
# Decision Tree (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (scratch) ---
#   Accuracy:    0.9580
#   Precision:   0.9544
#   Recall:      0.9390
#   Specificity: 0.9705
#   F1-Score:    0.9466
#   Confusion Matrix: TP=7449  FP=356  FN=484  TN=11711
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\decision_tree\model.pkl

# %%
# --- Random Forest (Scratch) ---
import src.modeling.classification.scratch.random_forest.train as scratch_random_forest_train
importlib.reload(scratch_random_forest_train)
scratch_random_forest_metrics = scratch_random_forest_train.train()
# Out:
# ============================================================
# Random Forest (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#   Trained tree 10/10
#
# --- Test Results (scratch) ---
#   Accuracy:    0.6034
#   Precision:   0.0000
#   Recall:      0.0000
#   Specificity: 1.0000
#   F1-Score:    0.0000
#   Confusion Matrix: TP=0  FP=0  FN=7933  TN=12067
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\random_forest\model.pkl

# %%
# --- SVM (Scratch) ---
import src.modeling.classification.scratch.svm.train as scratch_svm_train
importlib.reload(scratch_svm_train)
scratch_svm_metrics = scratch_svm_train.train()
# Out:
# ============================================================
# SVM (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#   Iteration 0, Loss: 0.999777
#   Iteration 200, Loss: 0.955204
#   Iteration 400, Loss: 0.911264
#   Iteration 600, Loss: 0.870505
#   Iteration 800, Loss: 0.839498
#
# --- Test Results (scratch) ---
#   Accuracy:    0.6660
#   Precision:   0.5826
#   Recall:      0.5567
#   Specificity: 0.7378
#   F1-Score:    0.5693
#   Confusion Matrix: TP=4416  FP=3164  FN=3517  TN=8903
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\svm\model.pkl

# %%
# --- Clustering (Scratch) ---
import src.modeling.classification.scratch.clustering.train as scratch_clustering_train
importlib.reload(scratch_clustering_train)
scratch_clustering_metrics = scratch_clustering_train.train()
# Out:
# ============================================================
# K-Means Clustering (from scratch)
# ============================================================
#   K-Means converged at iteration 16
#
# --- K-Means Results (mapped to true labels) ---
#   Accuracy:    0.5041
#   Precision:   0.4211
#   Recall:      0.6678
#   Specificity: 0.3964
#   F1-Score:    0.5165
#   Confusion Matrix: TP=26491  FP=36417  FN=13176  TN=23916
#   Inertia:         350539.06
#   Silhouette:      0.4672
#   Adjusted Rand:   -0.0028
#
# ============================================================
# Agglomerative Clustering (from scratch) — on 2 000 sample subset
# ============================================================
#
# --- Agglomerative Results (mapped to true labels) ---
#   Accuracy:    0.6015
#   Precision:   0.0000
#   Recall:      0.0000
#   Specificity: 0.9992
#   F1-Score:    0.0000
#   Confusion Matrix: TP=0  FP=1  FN=796  TN=1203
#   Silhouette:      0.4784
#   Adjusted Rand:   -0.0003
#
# Models saved to D:\SECTION\ML-PROJECT\models\classification\scratch\clustering\model.pkl

# %%
# --- XGBoost (Scratch) ---
import src.modeling.classification.scratch.xgboost.train as scratch_xgboost_train
importlib.reload(scratch_xgboost_train)
scratch_xgboost_metrics = scratch_xgboost_train.train()
# Out:
# ============================================================
# XGBoost Classifier (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#   [Round   10/100]  train_logloss=0.400262  val_logloss=0.400695
#   [Round   20/100]  train_logloss=0.296039  val_logloss=0.298480
#   [Round   30/100]  train_logloss=0.231696  val_logloss=0.235430
#   [Round   40/100]  train_logloss=0.189031  val_logloss=0.194379
#   [Round   50/100]  train_logloss=0.157275  val_logloss=0.163948
#   [Round   60/100]  train_logloss=0.140076  val_logloss=0.147205
#   [Round   70/100]  train_logloss=0.128940  val_logloss=0.136691
#   [Round   80/100]  train_logloss=0.118837  val_logloss=0.127034
#   [Round   90/100]  train_logloss=0.112491  val_logloss=0.121332
#   [Round  100/100]  train_logloss=0.105815  val_logloss=0.115287
#
# --- Test Results (scratch) ---
#   Accuracy:    0.9654
#   Precision:   0.9594
#   Recall:      0.9531
#   Specificity: 0.9735
#   F1-Score:    0.9562
#   Confusion Matrix: TP=7561  FP=320  FN=372  TN=11747
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\xgboost\model.pkl

# %%
# --- PCA + Random Forest (Scratch) ---
import src.modeling.classification.scratch.pca_random_forest.train as scratch_pca_rf_train
importlib.reload(scratch_pca_rf_train)
scratch_pca_random_forest_metrics = scratch_pca_rf_train.train()
# Out:
# PCA: 8 features -> 5 components
# Explained variance ratio: [9.98499580e-01 1.39944434e-03 9.23203035e-05 6.89878826e-06
#  1.09182846e-06]
# ============================================================
# Random Forest + PCA (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#   Trained tree 10/10
#
# --- Test Results (scratch + PCA) ---
#   Accuracy:    0.8061
#   Precision:   0.7520
#   Recall:      0.7625
#   Specificity: 0.8347
#   F1-Score:    0.7572
#   Confusion Matrix: TP=6049  FP=1995  FN=1884  TN=10072
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\pca_random_forest\model.pkl

# %%
# --- PCA + SVM (Scratch) ---
import src.modeling.classification.scratch.pca_svm.train as scratch_pca_svm_train
importlib.reload(scratch_pca_svm_train)
scratch_pca_svm_metrics = scratch_pca_svm_train.train()
# Out:
# PCA: 8 features -> 5 components
# ============================================================
# SVM + PCA (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#   Iteration 0, Loss: 0.999780
#   Iteration 200, Loss: 0.955813
#   Iteration 400, Loss: 0.912458
#   Iteration 600, Loss: 0.872017
#   Iteration 800, Loss: 0.841205
#
# --- Test Results (scratch + PCA) ---
#   Accuracy:    0.6612
#   Precision:   0.5769
#   Recall:      0.5463
#   Specificity: 0.7366
#   F1-Score:    0.5612
#   Confusion Matrix: TP=4334  FP=3178  FN=3599  TN=8889
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\pca_svm\model.pkl

# %%
# --- K-Means (Scratch) ---
import src.modeling.classification.scratch.kmeans.train as scratch_kmeans_train
importlib.reload(scratch_kmeans_train)
scratch_kmeans_metrics = scratch_kmeans_train.train()
# Out:
# ============================================================
# K-Means Clustering (from scratch)
# ============================================================
#   K-Means converged at iteration 16
#
# --- K-Means Results (mapped to true labels) ---
#   Accuracy:    0.5041
#   Precision:   0.4211
#   Recall:      0.6678
#   Specificity: 0.3964
#   F1-Score:    0.5165
#   Confusion Matrix: TP=26491  FP=36417  FN=13176  TN=23916
#   Inertia:         350539.06
#   Silhouette:      0.4672
#   Adjusted Rand:   -0.0028
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\kmeans\model.pkl

# %%
# --- Agglomerative (Scratch)
import src.modeling.classification.scratch.agglomerative.train as scratch_agglomerative_train
importlib.reload(scratch_agglomerative_train)
scratch_agglomerative_metrics = scratch_agglomerative_train.train()
# Out:
# ============================================================
# Agglomerative Clustering (from scratch) — on 2 000 sample subset
# ============================================================
#
# --- Agglomerative Results (mapped to true labels) ---
#   Accuracy:    0.5465
#   Precision:   0.3353
#   Recall:      0.1463
#   Specificity: 0.8094
#   F1-Score:    0.2037
#   Confusion Matrix: TP=116  FP=230  FN=677  TN=977
#   Silhouette:      0.4561
#   Adjusted Rand:   -0.0101
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\agglomerative\model.pkl

# %%
# --- SLP (Scratch) ---
import src.modeling.classification.scratch.slp.train as scratch_slp_train
importlib.reload(scratch_slp_train)
scratch_slp_metrics = scratch_slp_train.train()
# Out:
# ============================================================
# Single-Layer Perceptron (from scratch)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#   Epoch 0, Loss: 0.181823, Acc: 0.9372
#   Epoch 200, Loss: 0.166923, Acc: 0.9342
#   Epoch 400, Loss: 0.166912, Acc: 0.9350
#   Epoch 600, Loss: 0.166689, Acc: 0.9391
#   Epoch 800, Loss: 0.165246, Acc: 0.9363
#
# --- Test Results (scratch) ---
#   Accuracy:    0.9345
#   Precision:   0.9212
#   Recall:      0.9131
#   Specificity: 0.9486
#   F1-Score:    0.9171
#   Confusion Matrix: TP=7244  FP=620  FN=689  TN=11447
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\scratch\slp\model.pkl

# %%
# --- Logistic Regression (Lib) ---
import src.modeling.classification.lib.logistic_regression.train as sklearn_logistic_train
importlib.reload(sklearn_logistic_train)
sklearn_logistic_metrics = sklearn_logistic_train.train()
# Out:
# ============================================================
# Logistic Regression (sklearn)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (sklearn) ---
#   Accuracy:    0.9349
#   Precision:   0.9194
#   Recall:      0.9163
#   Specificity: 0.9472
#   F1-Score:    0.9179
#   Confusion Matrix: TP=7269  FP=637  FN=664  TN=11430
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\logistic_regression\model.pkl
#
# Feature Importance (%):
#   price: 32.94%
#   cpu_tier: 16.76%
#   gpu_tier: 14.22%
#   cpu_cores: 11.54%
#   cpu_threads: 11.49%
#   cpu_base_ghz: 10.28%
#   ram_gb: 2.48%
#   cpu_boost_ghz: 0.28%

# %%
# --- Perceptron (Lib) ---
import src.modeling.classification.lib.perceptron.train as sklearn_perceptron_train
importlib.reload(sklearn_perceptron_train)
sklearn_perceptron_metrics = sklearn_perceptron_train.train()
# Out:
# ============================================================
# Perceptron / SLP (sklearn)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (sklearn) ---
#   Accuracy:    0.9127
#   Precision:   0.9421
#   Recall:      0.8311
#   Specificity: 0.9664
#   F1-Score:    0.8831
#   Confusion Matrix: TP=6593  FP=405  FN=1340  TN=11662
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\perceptron\model.pkl

# %%
# --- MLP (Lib) ---
import src.modeling.classification.lib.mlp.train as sklearn_mlp_train
importlib.reload(sklearn_mlp_train)
sklearn_mlp_metrics = sklearn_mlp_train.train()
# Out:
# ============================================================
# Multi-Layer Perceptron (sklearn)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (sklearn) ---
#   Accuracy:    0.9718
#   Precision:   0.9666
#   Recall:      0.9622
#   Specificity: 0.9781
#   F1-Score:    0.9644
#   Confusion Matrix: TP=7633  FP=264  FN=300  TN=11803
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\mlp\model.pkl

# %%
# --- Decision Tree (Lib) ---
import src.modeling.classification.lib.decision_tree.train as sklearn_decision_tree_train
importlib.reload(sklearn_decision_tree_train)
sklearn_decision_tree_metrics = sklearn_decision_tree_train.train()
# Out:
# ============================================================
# Decision Tree (sklearn)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (sklearn) ---
#   Accuracy:    0.9582
#   Precision:   0.9543
#   Recall:      0.9396
#   Specificity: 0.9704
#   F1-Score:    0.9469
#   Confusion Matrix: TP=7454  FP=357  FN=479  TN=11710
#
# Feature Importance (%):
#   price: 40.93%
#   ram_gb: 23.30%
#   cpu_base_ghz: 10.64%
#   gpu_tier: 10.27%
#   cpu_tier: 6.82%
#   cpu_threads: 5.12%
#   cpu_boost_ghz: 1.74%
#   cpu_cores: 1.17%
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\decision_tree\model.pkl

# %%
# --- Random Forest (Lib) ---
import src.modeling.classification.lib.random_forest.train as sklearn_random_forest_train
importlib.reload(sklearn_random_forest_train)
sklearn_random_forest_metrics = sklearn_random_forest_train.train()
# Out:
# ============================================================
# Random Forest (sklearn)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (sklearn) ---
#   Accuracy:    0.9535
#   Precision:   0.9680
#   Recall:      0.9128
#   Specificity: 0.9802
#   F1-Score:    0.9396
#   Confusion Matrix: TP=7241  FP=239  FN=692  TN=11828
#
# Feature Importance (%):
#   price: 72.69%
#   gpu_tier: 6.14%
#   ram_gb: 4.42%
#   cpu_base_ghz: 4.38%
#   cpu_tier: 3.61%
#   cpu_boost_ghz: 3.27%
#   cpu_threads: 3.26%
#   cpu_cores: 2.23%
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\random_forest\model.pkl

# %%
# --- SVM (Lib) ---
import src.modeling.classification.lib.svm.train as sklearn_svm_train
importlib.reload(sklearn_svm_train)
sklearn_svm_metrics = sklearn_svm_train.train()
# Out:
# ============================================================
# SVM (sklearn)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (sklearn SVC) ---
#   Accuracy:    0.9349
#   Precision:   0.9208
#   Recall:      0.9147
#   Specificity: 0.9483
#   F1-Score:    0.9177
#   Confusion Matrix: TP=7256  FP=624  FN=677  TN=11443
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\svm\model.pkl

# %%
# --- Clustering (Lib) ---
import src.modeling.classification.lib.clustering.train as sklearn_clustering_train
importlib.reload(sklearn_clustering_train)
sklearn_clustering_metrics = sklearn_clustering_train.train()
# Out:
# ============================================================
# K-Means Clustering (sklearn)
# ============================================================
#
# --- K-Means Results (mapped to true labels) ---
#   Accuracy:    0.5042
#   Precision:   0.4212
#   Recall:      0.6677
#   Specificity: 0.3967
#   F1-Score:    0.5165
#   Confusion Matrix: TP=26484  FP=36396  FN=13183  TN=23937
#   Inertia:         350539.67
#   Silhouette:      0.4671
#   Adjusted Rand:   -0.0028
#
# ============================================================
# Agglomerative Clustering (sklearn)
# ============================================================
#
# --- Agglomerative Results (mapped to true labels) ---
#   Accuracy:    0.5595
#   Precision:   0.4388
#   Recall:      0.3832
#   Specificity: 0.6761
#   F1-Score:    0.4091
#   Confusion Matrix: TP=305  FP=390  FN=491  TN=814
#   Silhouette:      0.3532
#   Adjusted Rand:   0.0099
#
# Models saved to D:\SECTION\ML-PROJECT\models\classification\lib\clustering\model.pkl

# %%
# --- PCA + Random Forest (Lib) ---
import src.modeling.classification.lib.pca_random_forest.train as lib_pca_random_forest_train
importlib.reload(lib_pca_random_forest_train)
lib_pca_random_forest_metrics = lib_pca_random_forest_train.train()
# Out:
# PCA: 8 features -> 5 components
# Explained variance ratio: [9.98499580e-01 1.39944434e-03 9.23203035e-05 6.89878826e-06
#  1.09182846e-06]
# ============================================================
# Random Forest + PCA (sklearn)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (sklearn + PCA) ---
#   Accuracy:    0.9502
#   Precision:   0.9221
#   Recall:      0.9551
#   Specificity: 0.9470
#   F1-Score:    0.9383
#   Confusion Matrix: TP=7577  FP=640  FN=356  TN=11427
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\pca_random_forest\model.pkl

# %%
# --- PCA + SVM (Lib) ---
import src.modeling.classification.lib.pca_svm.train as lib_pca_svm_train
importlib.reload(lib_pca_svm_train)
lib_pca_svm_metrics = lib_pca_svm_train.train()
# Out:
# PCA: 8 features -> 5 components
# ============================================================
# SVM + PCA (sklearn)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (sklearn SVC + PCA) ---
#   Accuracy:    0.8755
#   Precision:   0.8459
#   Recall:      0.8390
#   Specificity: 0.8995
#   F1-Score:    0.8424
#   Confusion Matrix: TP=6656  FP=1213  FN=1277  TN=10854
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\pca_svm\model.pkl

# %%
# --- K-Means (Lib) ---
import src.modeling.classification.lib.kmeans.train as lib_kmeans_train
importlib.reload(lib_kmeans_train)
lib_kmeans_metrics = lib_kmeans_train.train()
# Out:
# ============================================================
# K-Means Clustering (sklearn)
# ============================================================
#
# --- K-Means Results (mapped to true labels) ---
#   Accuracy:    0.5042
#   Precision:   0.4212
#   Recall:      0.6677
#   Specificity: 0.3967
#   F1-Score:    0.5165
#   Confusion Matrix: TP=26484  FP=36396  FN=13183  TN=23937
#   Inertia:         350539.67
#   Silhouette:      0.4671
#   Adjusted Rand:   -0.0028
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\kmeans\model.pkl

# %%
# --- Agglomerative (Lib) ---
import src.modeling.classification.lib.agglomerative.train as lib_agglomerative_train
importlib.reload(lib_agglomerative_train)
lib_agglomerative_metrics = lib_agglomerative_train.train()
# Out:
# ============================================================
# Agglomerative Clustering (sklearn)
# ============================================================
#
# --- Agglomerative Results (mapped to true labels) ---
#   Accuracy:    0.5595
#   Precision:   0.4388
#   Recall:      0.3832
#   Specificity: 0.6761
#   F1-Score:    0.4091
#   Confusion Matrix: TP=305  FP=390  FN=491  TN=814
#   Silhouette:      0.3532
#   Adjusted Rand:   0.0099
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\agglomerative\model.pkl

# %%
# --- SLP (Lib) ---
import src.modeling.classification.lib.slp.train as lib_slp_train
importlib.reload(lib_slp_train)
lib_slp_metrics = lib_slp_train.train()
# Out:
# ============================================================
# Single-Layer Perceptron (sklearn)
# ============================================================
# Train samples: 80000  |  Test samples: 20000
#
# --- Test Results (sklearn) ---
#   Accuracy:    0.9353
#   Precision:   0.9199
#   Recall:      0.9167
#   Specificity: 0.9475
#   F1-Score:    0.9183
#   Confusion Matrix: TP=7272  FP=633  FN=661  TN=11434
#
# Model saved to D:\SECTION\ML-PROJECT\models\classification\lib\slp\model.pkl

# %%
models = [
    "Logistic Reg. (Scratch)", "Logistic Reg. (Lib)",
    "Perceptron (Scratch)", "Perceptron (Lib)",
    "SLP (Scratch)", "SLP (Lib)",
    "MLP (Scratch)", "MLP (Lib)",
    "Decision Tree (Scratch)", "Decision Tree (Lib)",
    "Random Forest (Scratch)", "Random Forest (Lib)",
    "PCA+RF (Scratch)", "PCA+RF (Lib)",
    "SVM (Scratch)", "SVM (Lib)",
    "PCA+SVM (Scratch)", "PCA+SVM (Lib)",
    "K-Means (Scratch)", "K-Means (Lib)",
    "Agglomerative (Scratch)", "Agglomerative (Lib)",
    "XGBoost (Scratch)",
]

accuracy_values = [
    scratch_logistic_metrics["accuracy"], sklearn_logistic_metrics["accuracy"],
    scratch_perceptron_metrics["accuracy"], sklearn_perceptron_metrics["accuracy"],
    scratch_slp_metrics["accuracy"], lib_slp_metrics["accuracy"],
    scratch_mlp_metrics["accuracy"], sklearn_mlp_metrics["accuracy"],
    scratch_decision_tree_metrics["accuracy"], sklearn_decision_tree_metrics["accuracy"],
    scratch_random_forest_metrics["accuracy"], sklearn_random_forest_metrics["accuracy"],
    scratch_pca_random_forest_metrics["accuracy"], lib_pca_random_forest_metrics["accuracy"],
    scratch_svm_metrics["accuracy"], sklearn_svm_metrics["accuracy"],
    scratch_pca_svm_metrics["accuracy"], lib_pca_svm_metrics["accuracy"],
    scratch_kmeans_metrics["accuracy"], lib_kmeans_metrics["accuracy"],
    scratch_agglomerative_metrics["accuracy"], lib_agglomerative_metrics["accuracy"],
    scratch_xgboost_metrics["accuracy"],
]

colors = ["steelblue" if "(Scratch)" in m else "darkorange" for m in models]

plt.figure(figsize=(18, 6))
bars = plt.bar(models, accuracy_values, color=colors)
plt.ylabel("Accuracy")
plt.title("Classification Model Comparison — Accuracy (Scratch vs Lib)")
plt.ylim(0, 1.05)
plt.xticks(rotation=45, ha="right")
for bar, val in zip(bars, accuracy_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01,
             f"{val:.4f}", ha="center", va="bottom", fontsize=8)
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %%
metrics_keys = ["precision", "recall", "f1"]
x = np.arange(len(models))
width = 0.25

all_metrics = [
    scratch_logistic_metrics, sklearn_logistic_metrics,
    scratch_perceptron_metrics, sklearn_perceptron_metrics,
    scratch_slp_metrics, lib_slp_metrics,
    scratch_mlp_metrics, sklearn_mlp_metrics,
    scratch_decision_tree_metrics, sklearn_decision_tree_metrics,
    scratch_random_forest_metrics, sklearn_random_forest_metrics,
    scratch_pca_random_forest_metrics, lib_pca_random_forest_metrics,
    scratch_svm_metrics, sklearn_svm_metrics,
    scratch_pca_svm_metrics, lib_pca_svm_metrics,
    scratch_kmeans_metrics, lib_kmeans_metrics,
    scratch_agglomerative_metrics, lib_agglomerative_metrics,
    scratch_xgboost_metrics,
]

plt.figure(figsize=(20, 6))
for i, key in enumerate(metrics_keys):
    values = [m[key] for m in all_metrics]
    plt.bar(x + i * width, values, width, label=key.capitalize())

plt.xticks(x + width, models, rotation=45, ha="right")
plt.ylabel("Score")
plt.title("Classification Model Comparison — Precision / Recall / F1 (Scratch vs Lib)")
plt.ylim(0, 1.05)
plt.legend()
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %%
# --- Confusion Matrix Summary Table ---
print(f"{'Model':<30} {'TP':>6} {'FP':>6} {'FN':>6} {'TN':>6} {'Accuracy':>10} {'F1':>8}")
print("-" * 72)
for name, m in zip(models, all_metrics):
    print(f"{name:<30} {m['tp']:>6} {m['fp']:>6} {m['fn']:>6} {m['tn']:>6} {m['accuracy']:>10.4f} {m['f1']:>8.4f}")
# Out:
# Model                              TP     FP     FN     TN   Accuracy       F1
# ------------------------------------------------------------------------
# Logistic Reg. (Scratch)          5419    694   2514  11373     0.8396   0.7716
# Logistic Reg. (Lib)              7269    637    664  11430     0.9349   0.9179
# Perceptron (Scratch)             6630    636   1303  11431     0.9031   0.8724
# Perceptron (Lib)                 6593    405   1340  11662     0.9127   0.8831
# SLP (Scratch)                    7244    620    689  11447     0.9345   0.9171
# SLP (Lib)                        7272    633    661  11434     0.9353   0.9183
# MLP (Scratch)                    6740   1028   1193  11039     0.8890   0.8585
# MLP (Lib)                        7633    264    300  11803     0.9718   0.9644
# Decision Tree (Scratch)          7449    356    484  11711     0.9580   0.9466
# Decision Tree (Lib)              7454    357    479  11710     0.9582   0.9469
# Random Forest (Scratch)             0      0   7933  12067     0.6034   0.0000
# Random Forest (Lib)              7241    239    692  11828     0.9535   0.9396
# PCA+RF (Scratch)                 6049   1995   1884  10072     0.8061   0.7572
# PCA+RF (Lib)                     7577    640    356  11427     0.9502   0.9383
# SVM (Scratch)                    4416   3164   3517   8903     0.6660   0.5693
# SVM (Lib)                        7256    624    677  11443     0.9349   0.9177
# PCA+SVM (Scratch)                4334   3178   3599   8889     0.6612   0.5612
# PCA+SVM (Lib)                    6656   1213   1277  10854     0.8755   0.8424
# K-Means (Scratch)               26491  36417  13176  23916     0.5041   0.5165
# K-Means (Lib)                   26484  36396  13183  23937     0.5042   0.5165
# Agglomerative (Scratch)           116    230    677    977     0.5465   0.2037
# Agglomerative (Lib)               305    390    491    814     0.5595   0.4091
# XGBoost (Scratch)                7561    320    372  11747     0.9654   0.9562

# %%
# --- Specificity / True Negative Rate Comparison ---
specificity_values = [m["specificity"] for m in all_metrics]

colors = ["steelblue" if "(Scratch)" in m else "darkorange" for m in models]

plt.figure(figsize=(18, 6))
bars = plt.bar(models, specificity_values, color=colors)
plt.ylabel("Specificity (TNR)")
plt.title("Classification Model Comparison — Specificity (Scratch vs Lib)")
plt.ylim(0, 1.05)
plt.xticks(rotation=45, ha="right")
for bar, val in zip(bars, specificity_values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01,
             f"{val:.4f}", ha="center", va="bottom", fontsize=8)
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %%
# --- ROC Curve & AUC ---
from sklearn.metrics import roc_curve, auc

roc_models = models
roc_metrics = all_metrics

plt.figure(figsize=(12, 8))
auc_scores = {}

for name, m in zip(roc_models, roc_metrics):
    y_true = np.asarray(m["y_test"])
    y_scores = np.asarray(m["y_scores"], dtype=float)

    fpr, tpr, _ = roc_curve(y_true, y_scores)
    roc_auc = auc(fpr, tpr)

    # Some models may output higher scores for the negative class.
    # If that happens, flip score direction so ROC reflects true ranking power.
    if roc_auc < 0.5:
        y_scores = -y_scores
        fpr, tpr, _ = roc_curve(y_true, y_scores)
        roc_auc = auc(fpr, tpr)

    auc_scores[name] = roc_auc
    linestyle = "-" if "(Scratch)" in name else "--"
    plt.plot(fpr, tpr, linewidth=2, linestyle=linestyle, label=f"{name} (AUC={roc_auc:.4f})")

plt.plot([0, 1], [0, 1], "k--", linewidth=1, label="Random (AUC=0.5)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - All Classification Models (Scratch vs Lib)")
plt.legend(loc="lower right", fontsize=7)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# --- AUC Bar Chart ---
auc_names = list(auc_scores.keys())
auc_vals = list(auc_scores.values())
colors = ["steelblue" if "(Scratch)" in n else "darkorange" for n in auc_names]

plt.figure(figsize=(18, 6))
bars = plt.bar(auc_names, auc_vals, color=colors)
plt.ylabel("AUC Score")
plt.title("AUC Score Comparison — All Classification Models (Scratch vs Lib)")
plt.ylim(0, 1.05)
plt.xticks(rotation=45, ha="right")
for bar, val in zip(bars, auc_vals):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01,
             f"{val:.4f}", ha="center", va="bottom", fontsize=8)
plt.grid(axis="y")
plt.tight_layout()
plt.show()

# %%
# --- Performance Curves: Training Loss & Accuracy ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# --- Left: Loss curves ---
ax = axes[0]
ax.plot(scratch_logistic_metrics["Loss History"], label="Logistic Reg.")
ax.plot(scratch_perceptron_metrics["Loss History"], label="Perceptron")
ax.plot(scratch_slp_metrics["Loss History"], label="SLP")
ax.plot(scratch_mlp_metrics["Loss History"], label="MLP")
ax.plot(scratch_svm_metrics["Loss History"], label="SVM")
ax.plot(scratch_xgboost_metrics["Loss History"], label="XGBoost")
ax.set_xlabel("Epoch / Iteration")
ax.set_ylabel("Loss")
ax.set_title("Training Loss Curves")
ax.legend()
ax.grid(True)

# --- Right: Accuracy curves ---
ax2 = axes[1]
ax2.plot(scratch_perceptron_metrics["Accuracy History"], label="Perceptron")
ax2.plot(scratch_slp_metrics["Accuracy History"], label="SLP")
ax2.plot(scratch_mlp_metrics["Accuracy History"], label="MLP")
ax2.set_xlabel("Epoch / Iteration")
ax2.set_ylabel("Accuracy")
ax2.set_title("Training Accuracy Curves")
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %%
# --- Full Metrics Summary Table ---
print(f"{'Model':<30} {'Acc':>8} {'Prec':>8} {'Recall':>8} {'Spec':>8} {'F1':>8} {'AUC':>8}")
print("-" * 92)
for name, m in zip(roc_models, roc_metrics):
    auc_val = auc_scores.get(name, 0)
    print(f"{name:<30} {m['accuracy']:>8.4f} {m['precision']:>8.4f} {m['recall']:>8.4f} "
          f"{m['specificity']:>8.4f} {m['f1']:>8.4f} {auc_val:>8.4f}")
# Out:
# Model                               Acc     Prec   Recall     Spec       F1      AUC
# --------------------------------------------------------------------------------------------
# Logistic Reg. (Scratch)          0.8396   0.8865   0.6831   0.9425   0.7716   0.9141
# Logistic Reg. (Lib)              0.9349   0.9194   0.9163   0.9472   0.9179   0.9822
# Perceptron (Scratch)             0.9031   0.9125   0.8357   0.9473   0.8724   0.9697
# Perceptron (Lib)                 0.9127   0.9421   0.8311   0.9664   0.8831   0.9775
# SLP (Scratch)                    0.9345   0.9212   0.9131   0.9486   0.9171   0.9821
# SLP (Lib)                        0.9353   0.9199   0.9167   0.9475   0.9183   0.9822
# MLP (Scratch)                    0.8890   0.8677   0.8496   0.9148   0.8585   0.9590
# MLP (Lib)                        0.9718   0.9666   0.9622   0.9781   0.9644   0.9971
# Decision Tree (Scratch)          0.9580   0.9544   0.9390   0.9705   0.9466   0.9870
# Decision Tree (Lib)              0.9582   0.9543   0.9396   0.9704   0.9469   0.9870
# Random Forest (Scratch)          0.6034   0.0000   0.0000   1.0000   0.0000   0.8313
# Random Forest (Lib)              0.9535   0.9680   0.9128   0.9802   0.9396   0.9930
# PCA+RF (Scratch)                 0.8061   0.7520   0.7625   0.8347   0.7572   0.8895
# PCA+RF (Lib)                     0.9502   0.9221   0.9551   0.9470   0.9383   0.9891
# SVM (Scratch)                    0.6660   0.5826   0.5567   0.7378   0.5693   0.7172
# SVM (Lib)                        0.9349   0.9208   0.9147   0.9483   0.9177   0.9823
# PCA+SVM (Scratch)                0.6612   0.5769   0.5463   0.7366   0.5612   0.7105
# PCA+SVM (Lib)                    0.8755   0.8459   0.8390   0.8995   0.8424   0.9489
# K-Means (Scratch)                0.5041   0.4211   0.6678   0.3964   0.5165   0.5321
# K-Means (Lib)                    0.5042   0.4212   0.6677   0.3967   0.5165   0.5322
# Agglomerative (Scratch)          0.5465   0.3353   0.1463   0.8094   0.2037   0.5395
# Agglomerative (Lib)              0.5595   0.4388   0.3832   0.6761   0.4091   0.5608
# XGBoost (Scratch)                0.9654   0.9594   0.9531   0.9735   0.9562   0.9938
