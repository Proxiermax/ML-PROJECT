# %%
import matplotlib.pyplot as plt
import src.modeling.multiple_regression.train as train

# %%
import importlib
importlib.reload(train)
metrics = train.train()
# Out:
# Scratch model saved!
# Sklearn model saved!

# %%
plt.figure()
plt.plot(metrics["Scratch Model Loss"])
plt.title("Scratch Training Loss (MSE)")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
mse_labels = [
    "Scratch Train",
    "Scratch Test",
    "Sklearn Train",
    "Sklearn Test"
]

mse_values = [
    metrics["Scratch Train MSE"],
    metrics["Scratch Test MSE"],
    metrics["Sklearn Train MSE"],
    metrics["Sklearn Test MSE"]
]

plt.figure()
plt.bar(mse_labels, mse_values)
plt.title("MSE Comparison")
plt.xticks(rotation=45)
plt.ylabel("MSE")
plt.show()

# %%
r2_labels = [
    "Scratch Train",
    "Scratch Test",
    "Sklearn Train",
    "Sklearn Test"
]

r2_values = [
    metrics["Scratch Train R2"],
    metrics["Scratch Test R2"],
    metrics["Sklearn Train R2"],
    metrics["Sklearn Test R2"]
]

plt.figure()
plt.bar(r2_labels, r2_values)
plt.title("R2 Score Comparison")
plt.xticks(rotation=45)
plt.ylabel("R2 Score")
plt.show()
